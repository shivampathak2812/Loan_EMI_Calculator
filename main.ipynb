# %%
import sys
sys.path.append('C:/Users/User/PycharmProjects/Loan_EMI_Calculator')

# %%
from calculator import calculate_emi, generate_schedule
from chart import plot_emi_chart

# %%
def main():
    print("=== Loan EMI Calculator ===")

# %%
    amount = float(input("Enter loan amount: "))
    rate = float(input("Enter annual interest rate (%): "))
    years = int(input("Enter tenure in years: "))
# Out:
# Enter loan amount:  500000
# Enter annual interest rate (%):  12
# Enter tenure in years:  5

# %%
emi = calculate_emi(amount, rate, years)
schedule = generate_schedule(amount, rate, years)

print("EMI:", emi)
# Out:
# EMI: 11122.223842450881

# %%
print("\n--- Amortization Schedule (First 12 Months) ---")
for row in schedule[:12]:
    print(row)
# Out:
# --- Amortization Schedule (First 12 Months) ---
# {'Month': 1, 'Interest Paid': 5000.0, 'Principal Paid': 6122.22, 'Remaining Balance': 493877.78}
# {'Month': 2, 'Interest Paid': 4938.78, 'Principal Paid': 6183.45, 'Remaining Balance': 487694.33}
# {'Month': 3, 'Interest Paid': 4876.94, 'Principal Paid': 6245.28, 'Remaining Balance': 481449.05}
# {'Month': 4, 'Interest Paid': 4814.49, 'Principal Paid': 6307.73, 'Remaining Balance': 475141.32}
# {'Month': 5, 'Interest Paid': 4751.41, 'Principal Paid': 6370.81, 'Remaining Balance': 468770.51}
# {'Month': 6, 'Interest Paid': 4687.71, 'Principal Paid': 6434.52, 'Remaining Balance': 462335.99}
# {'Month': 7, 'Interest Paid': 4623.36, 'Principal Paid': 6498.86, 'Remaining Balance': 455837.12}
# {'Month': 8, 'Interest Paid': 4558.37, 'Principal Paid': 6563.85, 'Remaining Balance': 449273.27}
# {'Month': 9, 'Interest Paid': 4492.73, 'Principal Paid': 6629.49, 'Remaining Balance': 442643.78}
# ...

# %%
plot_emi_chart(schedule)
